# %% [markdown]
# ### A2A Protocols using UV and python

# %% [markdown]
# - A2A  [ Agents to Agents communication]
#
#     A modern approach where autonomous s/w agents
#
#     - communicate,
#
#     - collaborate
#
#     - and make decision without human intervention
#
#
# - Sequential Order
#    -> GenAi
#    -> LLM
#    -> Agents
#    -> McP [ Interact with one agent]
#    -> A2A

# %% [markdown]
#  - LLM
#  - Agents
#  - MCP  [ Model Context protocol]
#  - Agentic AI framework
#      1. phidata (Agno AGI)
#      2. smolagents
#      3. crew AI
#      4. langchain

# %% [markdown]
# https://google.github.io/A2A/#a2a-unlock-collaborative-agent-to-agent-scenarios-with-a-new-open-protocol
#
# ![image.png](attachment:image.png)
#
# https://github.com/google/A2A

# %% [markdown]
# UV - Python [ Advanced python library and package/project manager]
#
# STEP 1 : Open A2A git hub
#                https://github.com/google/A2A
#
# STEP 2 : Create a new folder in VS code
#
# STEP 3 : Activate VS env
#   folder > python -m venv myenv
#          > activate
#
# STEP 4 : git clone   https://github.com/google/A2A.git

# %% [markdown]
# UV
# =======================
# replace pip
#
# > uv python install
#
# > pip install dotenv
#
# Generate API Key
#   > Go to google ai studio
#   > GOOGLE_KEY
#
#
# > pip install -q -U google-generativeai
#
# Api testing
# ==========
# curl "https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent?key=GOOGLE_KEY" \
# -H 'Content-Type: application/json' \
# -X POST \
# -d '{
#   "contents": [{
#     "parts":[{"text": "Explain how AI works"}]
#     }]
#    }'

# %% [markdown]
# Created .evn file and copy below contents under folder
#
#     -  / samples/python/agents/crewai
#
#     -  /samples/python/agents/google_adk
#
#     -  samples/python/agents/langgraph
#
#   GOOGLE_API_KEY=""

# %% [markdown]
# # run UV
#
# go to folder
#
#   - / samples/python/agents/crewai/> uv run .
#     http://localhost:10001
#
#   - / samples/python/agents/google_adk  > uv run .
#     http://localhost:10002
#
#   - / samples/python/agents/langgraph > uv run .
#     http://localhost:10000
#
# /demo/ui
#   > uv run main.py
#
#     http://localhost:12000
#
# # [ Important ] Add Remote agents  -> Take each 20 mins
#   > Add the above IP address
#
# - crewai [ Image generator agent]
#
#     http://localhost:10001
#
# - google_adk  [ Reimbursement agent]
#
#     http://localhost:10002
#
# - langgraph  [ Currency agent]
#
#     http://localhost:10000

# %% [markdown]
# Chat
# ========
# How many agents we have??

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Another project basic
#
#     [ https://google.github.io/A2A/tutorials/python/3-create-project/ ]

# %% [markdown]
# # create a project
#
# uv init --package my-project
# cd my-project
#
# uv venv .venv
#
# source .venv/bin/activate
#
# uv add git+https://github.com/google/A2A#subdirectory=samples/python
#
# Create below files
#
# touch src/my_project/agent.py
# touch src/my_project/task_manager.py
#
# # Test Run
#
#     > uv run my-project
#
# # Ouput
#
#     Hello from my-project!
